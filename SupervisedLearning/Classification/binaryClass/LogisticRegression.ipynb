# %% [markdown]
# LogisticRegression :-binary classification

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'D:\Documents\PROJECTS\MachineLearning\SupervisedLearning\Classification\insurance_data.csv')
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age,df.bought_insurance)
plt.xlabel("Age ")
plt.ylabel("bought or Not")
# Out:
# Text(0, 0.5, 'bought or Not')

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(df[['age']],df.bought_insurance,train_size=0.9)

# %%
X_test
# Out:
#     age
# 13   29
# 23   45
# 7    60

# %%
X_train
# Out:
#     age
# 0    22
# 15   55
# 16   25
# 25   54
# 20   21
# 12   27
# 8    62
# 2    47
# 6    55
# 24   50
# 4    46
# 10   18
# 26   23
# 1    25
# 5    56
# 18   19
# 11   28
# 3    52
# 9    61
# 17   58
# 19   18
# 14   49
# 22   40
# 21   26

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 1, 1])

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
model.predict_proba(X_test)
# Out:
# array([[0.78351018, 0.21648982],
#        [0.32581153, 0.67418847],
#        [0.06819309, 0.93180691]])

# %%
print(model.coef_.shape)
# Out:
# (1, 1)

# %%
model.predict(np.array([[23]]))
# Out:
# c:\Users\ACER\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])
